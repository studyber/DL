# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import * 
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Load the OCR letter recognition dataset, Link
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data'
# dataset = pd.read_csv(url, header=None)

# %%
# Load the OCR letter recognition dataset
url = 'letter-recognition.data'
df = pd.read_csv(url, header=None)

# %%
# Split the dataset into features and labels
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %%
# Encode the labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(X_train)
# Out:
# [[ 3  8  4 ...  8  6  8]
#  [ 5 11  7 ...  7  8  8]
#  [ 6 10  9 ...  8  6  7]
#  ...
#  [ 7  9  6 ...  8  3  4]
#  [ 3  1  4 ...  5  2  8]
#  [ 4  8  5 ... 10  3  5]]

# %%
X_train = X_train / 15.0
X_test = X_test / 15.0

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(16,)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(26, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics =['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=12)
# Out:
# Epoch 1/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 2.6791 - accuracy: 0.2015 - val_loss: 1.7879 - val_accuracy: 0.5525
# Epoch 2/50
# 1334/1334 [==============================] - 2s 1ms/step - loss: 1.8780 - accuracy: 0.4096 - val_loss: 1.3666 - val_accuracy: 0.6320
# Epoch 3/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.6152 - accuracy: 0.4874 - val_loss: 1.1957 - val_accuracy: 0.6842
# Epoch 4/50
# 1334/1334 [==============================] - 2s 1ms/step - loss: 1.4797 - accuracy: 0.5354 - val_loss: 1.0997 - val_accuracy: 0.6933
# Epoch 5/50
# 1334/1334 [==============================] - 2s 1ms/step - loss: 1.3857 - accuracy: 0.5632 - val_loss: 1.0180 - val_accuracy: 0.7085
# Epoch 6/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.3221 - accuracy: 0.5811 - val_loss: 0.9683 - val_accuracy: 0.7245
# Epoch 7/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.2575 - accuracy: 0.6047 - val_loss: 0.9317 - val_accuracy: 0.7287
# Epoch 8/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.2301 - accuracy: 0.6071 - val_loss: 0.9186 - val_accuracy: 0.7243
# Epoch 9/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.1937 - accuracy: 0.6196 - val_loss: 0.8604 - val_accuracy: 0.7513
# Epoch 10/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.1710 - accuracy: 0.6274 - val_loss: 0.8353 - val_accuracy: 0.7575
# Epoch 11/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.1357 - accuracy: 0.6422 - val_loss: 0.8141 - val_accuracy: 0.7600
# Epoch 12/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.1223 - accuracy: 0.6426 - val_loss: 0.7775 - val_accuracy: 0.7715
# Epoch 13/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.1046 - accuracy: 0.6470 - val_loss: 0.7817 - val_accuracy: 0.7680
# Epoch 14/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0744 - accuracy: 0.6571 - val_loss: 0.7628 - val_accuracy: 0.7755
# Epoch 15/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0708 - accuracy: 0.6609 - val_loss: 0.7338 - val_accuracy: 0.7788
# Epoch 16/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0436 - accuracy: 0.6715 - val_loss: 0.7355 - val_accuracy: 0.7870
# Epoch 17/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0468 - accuracy: 0.6656 - val_loss: 0.7163 - val_accuracy: 0.7860
# Epoch 18/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0337 - accuracy: 0.6741 - val_loss: 0.6973 - val_accuracy: 0.7908
# Epoch 19/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0214 - accuracy: 0.6751 - val_loss: 0.7004 - val_accuracy: 0.7958
# Epoch 20/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0109 - accuracy: 0.6782 - val_loss: 0.6922 - val_accuracy: 0.7965
# Epoch 21/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0037 - accuracy: 0.6782 - val_loss: 0.6732 - val_accuracy: 0.7987
# Epoch 22/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9822 - accuracy: 0.6875 - val_loss: 0.6873 - val_accuracy: 0.7960
# Epoch 23/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9828 - accuracy: 0.6930 - val_loss: 0.6576 - val_accuracy: 0.8120
# Epoch 24/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9800 - accuracy: 0.6854 - val_loss: 0.6640 - val_accuracy: 0.8110
# Epoch 25/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9762 - accuracy: 0.6896 - val_loss: 0.6487 - val_accuracy: 0.8080
# Epoch 26/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9666 - accuracy: 0.6911 - val_loss: 0.6458 - val_accuracy: 0.8037
# Epoch 27/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9617 - accuracy: 0.6959 - val_loss: 0.6243 - val_accuracy: 0.8145
# Epoch 28/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9536 - accuracy: 0.6971 - val_loss: 0.6272 - val_accuracy: 0.8117
# Epoch 29/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9581 - accuracy: 0.6946 - val_loss: 0.6348 - val_accuracy: 0.8170
# Epoch 30/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9433 - accuracy: 0.7016 - val_loss: 0.6168 - val_accuracy: 0.8190
# Epoch 31/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9331 - accuracy: 0.7040 - val_loss: 0.6361 - val_accuracy: 0.8115
# Epoch 32/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9235 - accuracy: 0.7044 - val_loss: 0.5998 - val_accuracy: 0.8207
# Epoch 33/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9144 - accuracy: 0.7077 - val_loss: 0.6065 - val_accuracy: 0.8170
# Epoch 34/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9152 - accuracy: 0.7099 - val_loss: 0.5953 - val_accuracy: 0.8245
# Epoch 35/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9243 - accuracy: 0.7077 - val_loss: 0.6061 - val_accuracy: 0.8207
# Epoch 36/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9094 - accuracy: 0.7056 - val_loss: 0.5885 - val_accuracy: 0.8223
# Epoch 37/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9138 - accuracy: 0.7097 - val_loss: 0.5838 - val_accuracy: 0.8257
# Epoch 38/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8979 - accuracy: 0.7163 - val_loss: 0.5764 - val_accuracy: 0.8265
# Epoch 39/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9190 - accuracy: 0.7080 - val_loss: 0.5613 - val_accuracy: 0.8307
# Epoch 40/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8998 - accuracy: 0.7163 - val_loss: 0.5703 - val_accuracy: 0.8300
# Epoch 41/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8989 - accuracy: 0.7137 - val_loss: 0.5658 - val_accuracy: 0.8310
# Epoch 42/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9015 - accuracy: 0.7126 - val_loss: 0.5635 - val_accuracy: 0.8295
# Epoch 43/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8961 - accuracy: 0.7188 - val_loss: 0.5753 - val_accuracy: 0.8288
# Epoch 44/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8916 - accuracy: 0.7188 - val_loss: 0.5642 - val_accuracy: 0.8315
# Epoch 45/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8883 - accuracy: 0.7161 - val_loss: 0.5586 - val_accuracy: 0.8307
# Epoch 46/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8954 - accuracy: 0.7132 - val_loss: 0.5566 - val_accuracy: 0.8347
# Epoch 47/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8913 - accuracy: 0.7160 - val_loss: 0.5619 - val_accuracy: 0.8340
# Epoch 48/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8743 - accuracy: 0.7191 - val_loss: 0.5605 - val_accuracy: 0.8317
# Epoch 49/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8715 - accuracy: 0.7194 - val_loss: 0.5596 - val_accuracy: 0.8290
# Epoch 50/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.8781 - accuracy: 0.7241 - val_loss: 0.5422 - val_accuracy: 0.8325

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", accuracy)
print("Test loss:", loss)
# Out:
# 125/125 [==============================] - 0s 1ms/step - loss: 0.5422 - accuracy: 0.8325
# Test accuracy: 0.8324999809265137
# Test loss: 0.5421750545501709

# %%
model.save('ocr_model.h5')
# Save the trained model

# %%
from tensorflow.keras.models import load_model
model = load_model('ocr_model.h5')
# Load the trained model

# %%
sample_records = X_test[:1000]
# Select a few records for classification

# %%
# Perform classification
predictions = model.predict(sample_records)

# %%
predicted_labels = np.argmax(predictions, axis=1)

# %%
predicted_letters = label_encoder.inverse_transform(predicted_labels)
actual_letters = label_encoder.inverse_transform(y_test)

# %%
# Print the predicted labels and corresponding actual labels
print("Predicted Labels\tActual Labels")
for i in range(len(predicted_letters)):
    print(f"{predicted_letters[i]}\t\t\t{actual_letters[i]}")
# Out:
# Predicted Labels	Actual Labels
# D			D
# D			D
# V			V
# B			B
# H			H
# N			N
# R			E
# Q			Q
# E			R
# N			N
# Q			Q
# W			O
# N			N
# D			D
# J			I
# M			M
# U			U
# S			S
# O			O
# A			A
# X			X
# A			A
# K			K
# S			S
# O			O
# V			V
# Y			Y
# J			J
# D			D
# V			V
# D			D
# V			V
# K			K
# T			F
# N			N
# I			I
# G			G
# T			T
# H			H
# K			K
# J			J
# O			O
# M			M
# T			T
# B			B
# Q			Q
# Z			Z
# C			C
# D			D
# X			X
# K			C
# G			G
# Q			Q
# F			F
# N			N
# Y			Y
# Z			Z
# K			K
# C			C
# K			T
# M			M
# W			V
# G			G
# R			M
# D			D
# T			T
# H			H
# P			P
# N			N
# C			C
# O			O
# X			X
# X			X
# Q			Q
# V			V
# F			P
# V			V
# G			G
# W			W
# O			H
# P			P
# O			O
# I			I
# G			G
# X			X
# Y			X
# Y			P
# W			W
# Q			Q
# D			D
# D			N
# G			Q
# T			T
# T			T
# V			V
# Y			Y
# I			T
# V			V
# J			J
# M			U
# D			D
# L			L
# M			M
# Y			Y
# E			E
# M			M
# A			A
# Y			Y
# K			K
# Y			Y
# U			U
# U			U
# U			U
# K			C
# Q			Q
# I			I
# A			A
# E			E
# B			D
# T			T
# B			P
# Q			Q
# Z			Z
# G			G
# X			X
# G			G
# F			F
# M			M
# S			S
# E			E
# E			E
# K			K
# Z			Z
# K			X
# O			O
# E			E
# G			U
# I			I
# R			R
# O			O
# M			M
# J			J
# F			F
# K			K
# M			M
# N			N
# U			T
# D			D
# H			H
# R			R
# L			L
# Z			Z
# F			F
# V			V
# W			W
# E			E
# T			T
# W			W
# Y			Y
# Q			Q
# L			L
# F			F
# O			O
# D			D
# K			K
# S			I
# X			X
# P			P
# H			H
# Q			Z
# D			H
# W			W
# T			F
# B			B
# R			R
# O			O
# B			B
# S			Z
# N			N
# W			W
# Z			Z
# W			W
# V			V
# B			S
# Y			Y
# H			H
# Q			O
# T			Y
# V			V
# S			S
# W			W
# B			B
# P			P
# D			D
# Z			Z
# O			O
# X			X
# F			P
# B			B
# S			S
# T			T
# X			X
# J			J
# B			B
# Y			Y
# J			I
# Z			Z
# Z			Z
# P			P
# E			E
# R			H
# Q			Q
# F			I
# A			A
# H			H
# F			P
# E			E
# U			U
# K			K
# P			P
# N			M
# C			C
# X			Y
# J			J
# W			W
# M			M
# G			G
# J			J
# O			O
# K			H
# V			P
# L			L
# W			W
# A			A
# C			C
# C			C
# C			C
# O			O
# J			J
# Y			Y
# P			P
# Y			Y
# A			A
# R			R
# Z			Z
# J			J
# I			I
# G			G
# G			G
# I			I
# X			K
# R			M
# R			R
# T			T
# X			D
# E			E
# D			D
# L			L
# W			W
# G			P
# L			L
# U			U
# O			O
# T			T
# A			A
# V			V
# D			D
# U			U
# X			X
# X			X
# G			G
# C			C
# D			F
# Z			Z
# W			W
# T			T
# V			V
# T			T
# P			P
# M			M
# S			S
# U			U
# X			F
# Q			Q
# B			B
# G			G
# X			K
# L			L
# F			F
# E			E
# R			R
# P			P
# R			R
# W			W
# I			I
# Y			Y
# Y			Y
# B			B
# C			C
# T			T
# M			M
# M			M
# O			N
# B			B
# R			R
# Z			Z
# G			G
# D			D
# R			R
# I			I
# Y			Y
# F			P
# M			M
# A			A
# B			B
# M			M
# R			F
# G			G
# Q			Q
# Z			Z
# P			P
# O			O
# Q			Q
# P			P
# G			G
# N			N
# O			O
# T			T
# G			G
# S			S
# V			V
# A			Z
# A			A
# D			P
# J			J
# O			O
# N			N
# B			Q
# K			K
# X			X
# S			E
# F			P
# J			J
# N			N
# X			X
# X			X
# V			V
# Q			Q
# Y			H
# A			A
# T			T
# S			S
# W			W
# M			M
# P			P
# Y			Y
# K			U
# S			Z
# R			R
# B			B
# A			A
# Y			Y
# F			F
# X			F
# D			D
# A			A
# N			N
# A			A
# R			H
# Q			Q
# P			P
# Z			Z
# R			R
# D			D
# W			W
# R			O
# Q			Q
# K			K
# N			N
# W			W
# P			P
# W			W
# S			S
# K			K
# S			S
# I			J
# E			E
# S			S
# V			V
# S			S
# O			O
# V			V
# G			T
# X			X
# Q			Q
# W			W
# I			I
# Z			Z
# B			D
# F			F
# P			P
# W			R
# P			P
# C			C
# D			D
# J			J
# R			L
# I			I
# H			H
# X			X
# B			D
# U			U
# G			G
# O			O
# K			K
# K			K
# K			K
# P			P
# P			P
# G			G
# T			T
# T			F
# B			B
# Y			Y
# V			Y
# I			I
# H			H
# E			E
# Z			S
# Y			Y
# S			S
# T			T
# Q			Q
# L			L
# R			M
# I			I
# Z			Z
# F			F
# A			A
# J			J
# B			V
# G			G
# U			U
# Z			Z
# H			H
# O			O
# D			N
# J			J
# X			T
# O			O
# H			H
# Q			V
# F			F
# L			L
# W			W
# M			M
# T			Y
# J			J
# P			P
# W			W
# E			E
# A			A
# B			B
# N			N
# W			O
# Q			Q
# Y			Y
# Q			Q
# F			F
# A			A
# A			A
# Q			Q
# Z			Z
# E			E
# R			H
# N			N
# E			E
# A			A
# R			R
# C			C
# Z			Z
# Q			Q
# V			V
# O			O
# D			T
# K			K
# M			M
# R			R
# Y			Y
# X			X
# X			X
# J			J
# X			X
# Q			Q
# T			T
# S			S
# A			A
# X			X
# G			G
# T			T
# N			N
# S			S
# Y			Y
# P			P
# A			A
# S			I
# T			T
# Q			X
# X			X
# C			C
# O			O
# B			B
# G			G
# K			W
# D			D
# K			K
# U			U
# S			S
# W			O
# Z			Z
# S			L
# H			N
# R			R
# V			V
# A			A
# K			L
# B			D
# W			W
# I			I
# O			O
# C			C
# W			W
# A			A
# Y			Y
# Q			Q
# L			L
# G			Q
# K			K
# J			J
# E			E
# B			B
# P			P
# J			J
# R			R
# X			X
# N			N
# A			A
# G			G
# C			C
# H			T
# L			L
# S			S
# A			A
# N			N
# B			K
# V			V
# B			G
# A			A
# D			D
# H			H
# V			Y
# Z			Z
# Q			Q
# C			C
# U			U
# Q			Q
# Z			Z
# M			M
# D			D
# D			B
# L			L
# R			R
# D			Q
# D			D
# F			F
# W			W
# Q			Q
# M			M
# G			G
# Z			Z
# B			B
# U			U
# N			N
# K			K
# P			P
# A			A
# W			U
# F			F
# T			T
# X			X
# L			L
# U			U
# Y			Y
# P			P
# Y			Y
# R			R
# S			S
# K			K
# G			E
# Q			Q
# F			F
# W			W
# P			P
# P			P
# M			M
# N			N
# Z			Z
# G			G
# B			K
# O			O
# W			W
# I			I
# F			C
# E			E
# U			U
# R			R
# F			I
# Y			Y
# S			S
# V			V
# R			R
# C			C
# Q			Q
# C			C
# Z			J
# Y			Y
# S			S
# K			K
# G			L
# X			X
# T			T
# I			I
# B			F
# W			W
# A			A
# Q			D
# K			K
# A			A
# Z			Z
# M			M
# G			G
# G			G
# W			W
# W			W
# Z			Z
# W			W
# T			T
# O			O
# R			R
# T			T
# N			N
# S			S
# Q			Q
# J			J
# Q			Q
# M			M
# O			O
# A			A
# N			N
# Z			Z
# D			D
# T			T
# I			I
# U			U
# A			A
# W			N
# U			G
# G			P
# L			L
# T			F
# R			R
# C			C
# P			P
# T			Y
# Y			Y
# T			T
# A			A
# S			Y
# T			T
# G			E
# T			T
# O			O
# S			S
# N			N
# O			O
# I			I
# O			O
# U			U
# N			N
# Z			Z
# J			J
# C			C
# N			H
# S			S
# G			L
# H			H
# E			C
# Q			Q
# F			F
# B			B
# W			O
# I			I
# K			K
# O			O
# H			R
# E			E
# L			L
# M			M
# L			L
# X			T
# E			E
# U			U
# W			W
# E			F
# D			D
# N			N
# V			V
# M			M
# I			I
# X			K
# L			L
# T			Y
# Q			Q
# F			F
# U			U
# J			J
# V			V
# M			M
# P			P
# W			W
# L			L
# A			A
# L			L
# B			B
# Y			Y
# I			I
# D			D
# R			R
# T			T
# Q			Q
# B			B
# O			U
# M			M
# O			O
# L			I
# U			U
# U			U
# X			K
# S			J
# I			I
# W			W
# Z			Z
# Z			Z
# P			P
# A			A
# Z			Z
# P			P
# V			V
# O			G
# B			B
# G			G
# O			O
# V			V
# D			D
# Z			Z
# Y			Y
# P			P
# Q			Q
# A			A
# E			E
# W			W
# D			D
# J			J
# I			I
# J			J
# X			X
# B			S
# Z			Z
# G			G
# X			T
# U			U
# K			K
# G			G
# I			I
# N			N
# Z			I
# W			W
# I			I
# I			I
# D			P
# B			B
# O			O
# H			H
# F			D
# O			O
# N			N
# Z			S
# D			D
# E			S
# M			M
# O			O
# W			N
# Y			Y
# X			X
# Q			Q
# W			M
# R			R
# G			G
# G			G
# A			A
# B			K
# U			U
# U			O
# G			P
# C			C
# V			V
# D			D
# B			B
# A			A
# C			E
# D			R
# T			T
# I			I
# S			Z
# N			N
# O			O
# B			B
# C			C
# G			G
# J			J
# E			E
# N			N
# J			J
# Q			H
# D			P
# O			O
# O			O
# B			B
# X			X
# D			D
# S			S
# O			O
# O			O
# G			G
# R			B
# R			H
# C			C
# A			A
# W			W
# P			P
# I			I
# N			N
# M			M
# K			G
# H			N
# A			A
# A			H
# U			K
# N			N
# M			M
# F			F
# W			W
# A			A
# S			S
# E			E
# B			T
# J			J
# H			H
# N			N
# K			K
# W			W
# W			W
# U			U
# L			L
# Z			Z
# Z			Z
# Z			Z
# G			G
# T			T
# J			J
# V			V
# W			W
# L			L
# M			M
# U			U
# W			W
# O			G
# A			A
# T			T
# J			J
# C			C
# G			G
# D			D
# T			Y
# Y			Y
# X			X
# N			N
# Y			Y
# Z			S
# K			K
# U			U
# W			W
# R			R
# B			B
# T			T
# R			R
# H			H
# R			R
# M			M
# O			O
# W			W
# X			X
# R			R
# X			X
# N			N
# H			H
# C			C
# C			C
# J			J
# V			V
# V			V
# I			I
# R			R
# W			W
# O			H
# N			N
# E			E
# U			U
# A			M
# A			A
# B			B
# E			E
# K			K
# T			T
# F			F
# Y			Y
# H			T
# H			H
# W			W
# W			W
# O			O
# Q			G
# W			W
# L			L
# Q			Q
# R			R
# K			K
# B			D
# P			P
# T			T
# S			B
# B			L
# V			V
# Q			Q
# G			G
# E			S
# O			W
# V			V
# L			L
# D			D
# K			R
# L			L
# C			C
# N			N
# V			V
# I			I
# P			P
# K			C
# F			F
# W			W
# A			A
# P			P
# T			T
# H			H
# B			B
# K			K
# I			I
# W			W
# B			R
# J			J
# K			R
# K			K
# A			A
# Q			Q
# Q			Q
# A			A
# M			M
# V			V
# U			U
# G			G
# O			O
# U			U
# H			H
# V			V
# G			G
# Q			Q
# I			I
# T			T
# L			G
# P			I
